# %% [markdown]
# # Data Visualization using pandas inbuilt functions, matplotlib and seaborn

# %% [markdown]
# Data visualization is the representation of data or information in a graph, chart, or other visual format.Machine learning makes it easier to conduct analyses such as predictive analysis, which can then serve as helpful visualizations to present
#
# In general, there are two different types of data visualization: exploration, which helps find a story the data is telling you, and an explanation, which tells a story to an audience. Both types of data visualization must take into account the audience's expectations
#
#
# #### Why Visualization?
#
# Do you think giving you the data of lets say 1 Million points in a table/Database file and asking you to provide your inferences by just seeing the data on that table is feasible? Unless you’re a super human its not possible. This is when we make use of Data visualization, wherein all the data will be transformed into some form of plots and analyzed further from that. As being a human, we are more used to grasp a lot of info from diagrammatic representation than the counterparts
#
# From perspective of building models , By visualizing the data we can find the hidden patterns, Explore if there are any clusters within data and we can find if they are linearly separable/too much overlapped etc. From this initial analysis we can easily rule out the models that won’t be suitable for such a data and we will implement only the models that are suitable, without wasting our valuable time and the computational resources.
# This part of data visualization is a predominant one in initial Exploratory Data Analysis (EDA) on the field of Data science/ML.

# %% [markdown]
# #### Dimensionality Reduction Techniques
#
# As a human, we can just visualize anything in either in 2-d or 3-d. But trust me almost of the data that you obtain in real world won’t be this way. As a Machine learning engineer, working with more than 1000-dimensional data is very common. So what can we do in such cases where data is more than 3D ? There are some Dimensionality Reduction(DR) techniques like PCA, TSNE , LDA etc which helps you to convert data from a higher dimension to a 2D or 3D data in order to visualize them. There may be some loss of information with each DR techniques, but only they can help us visualize very high dimensional data on a 2d plot. TSNE is one of the state of the art DR technique employed for visualization of high dimensional data

# %% [markdown]
# #### Different types of analysis:
#
# There are different types of analysis as mentioned below.
#
# 1. Univariate : In univariate analysis we will be using a single feature to analyze almost of its properties.
#
# 2. Bivariate : When we compare the data between exactly 2 features then its called bivariate analysis.
#
# 3. Multivariate: Comparing more than 2 variables is called as Multivariate analysis.

# %% [markdown]
# #### Most useful plots (for data exploration) used in Machine Learning for each type of analayis (though it's not limited to below usage)
#
# ##### 1. Scatter plot (Bivariate)
#
# * This plot gives us a representation of where each points in the entire dataset are present with respect to any 2/3 features, where we will primarily find patterns/Clusters and separability of the data
#
# ![image.png](attachment:image.png)
#
# #####  2. Pair plot (Multivariate)
#
# * Lets say we have n number of features in a data, Pair plot will create us a (n x n) figure where the diagonal plots will be histogram plot of the feature corresponding to that row and rest of the plots are the combination of feature from each row in y axis and feature from each column in x axis.
#
# ![image-2.png](attachment:image-2.png)
#
# ##### 3. Box plot (Univariate)
#
# * This is the type of plot that can be used to obtain more of the statistical details about the data. The straight lines at the maximum and minimum are also called as whiskers. Points outside of whiskers will be inferred as an outliers. The box plot gives us a representation of 25th, 50th ,75th quartiles.From box plot we can also see the Interquartile range(IQR) where maximum details of the data will be present. It also gives us a clear overview of outlier points in the data
#
# ![image-3.png](attachment:image-3.png)
#
# ##### 4. Violin plot(Univariate)
#
# * The violin plots can be inferred as a combination of Box plot at the middle and distribution plots(Kernel Density Estimation ) on both side of the data. This can give us the details of distribution like whether the distribution is mutimodal, Skewness etc. It also give us the useful info like 95% confidence interval. The below image help us grasp some important parts from a violin plot
# ![image-4.png](attachment:image-4.png)
#
# ##### 5. Distribution plot (Univariate)
#
# * This is one of the best univariate plot to know about the distribution of data. When analyzing effect on dependent variable(output) with respective to a single feature(input), we use distribution plots a lot. This plot gives us a combination of pdf and histogram in a single figure.
#
# ![image-5.png](attachment:image-5.png)
#
# ##### 6. Joint plot(Univariate) & (Bivariate)
#
# * This plot will represents both univariate as well as bivariate analysis. The main plot will give us a bivariate analysis, whereas on the top and right side we will get univariate plots of both the variables that were considered.There are variety of option you can choose from, which can be tuned using kind parameter in seaborn’s jointplot function. The one shown below is of kind as KDE( Kernel Density Estimation) and it is represented in a contour diagram, All points with same boundary will have the same value and the colour at a point depends on number of datapoints i.e it will be light color when very few points had that value and will be darker with more points. This is why at center it is darker and will be pale/lighter at the ends for this dataset.
#
# ![image-6.png](attachment:image-6.png)
#
# ##### 7. Bar chart (Bivariate)
#
# ![image-7.png](attachment:image-7.png)
#
# ##### 8. Line plot(Bivariate)
#
# * The line plots are nothing but the values on series of datapoints will be connected with straight lines
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# References:
#
# https://towardsdatascience.com/data-visualization-for-machine-learning-and-data-science-a45178970be7
#
# https://towardsdatascience.com/histograms-and-density-plots-in-python-f6bda88f5ac0

# %% [markdown]
# ##### Let's explore above techniques using inbuilt DataFrame's functions, matplotlib and seaborn library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#Below line of code will help in avoiding wrirting plt.show() code to use for every plotting 
# %matplotlib inline

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Scatter Plot
# This kind of plot is useful to see complex correlations between two variables. Points could be for instance natural 2D coordinates like longitude and latitude in a map or, in general, any pair of metrics that can be plotted against each other.

# %%
# Scatter plot using inbuilt 'plot' function of DataFrame
iris.plot(kind='scatter',x='sepal_length',y='petal_length',c='orange')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# #### plot() Makes plots of Series or DataFrame , 'Kind' parameter is used to specify the type of plot
#
# The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
# Alternatively, Scatter plot using inbuilt 'scatter' function of DataFrame
fig = iris.plot.scatter(x='sepal_length',y='petal_length',c='cyan')
fig.set_title("Scatter Plot of Iris dataset")
fig.set_xlabel("X-> Sepal Length")
fig.set_ylabel("Y-> Petal Length")
# Out:
# Text(0, 0.5, 'Y-> Petal Length')

# %%
# Scatter plot using scatter() from 'matplotlib' library
plt.scatter(iris['sepal_length'],iris['petal_length'],c='green')

# %%
plt.scatter(iris['sepal_length'],iris['petal_length'],c='magenta')
plt.xlabel("sepal_length")
plt.ylabel("petal_length")
plt.title("Example of Scatter Plot")
plt.savefig("c:\\users\\dasam\\desktop\\scatterplot.jpeg")

# %% [markdown]
# Now how it would be if we can color the points as per their class label. Here the class labels are Setosa, Virginica and Veriscolor. This is where Seaborn pops up, with its effective visualization stuffs

# %%
# Scatterplot using matplotlib
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=5) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()

# %% [markdown]
# We can conclude like setosa flowers are well separated from the other 2 classes and also there are some overlaps between virginica and versicolor. The parameter hue, in the facetGrid decides the color of each datapoints. Here we used Species column(dependent feature/Class) in hue, so that we got this plot colored in this manner.
#
# This makes seaborn a bit more superior than Matplotlib when it comes to visualization. But not to forget that still we are using plt.scatter from Matplotlib, on the map function in seaborn. So seaborn is just making the visual more appealing

# %% [markdown]
# ### Pair Plot
#
# Lets say we have n number of features in a data, Pair plot will create us a (n x n) figure where the diagonal plots will be histogram plot of the feature corresponding to that row and rest of the plots are the combination of feature from each row in y axis and feature from each column in x axis.

# %%
# Pairplotting through Scatter_matrix using built-in DataFrame functions
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize= (15,15), diagonal='kde',alpha=1.0)
plt.show()

# %%
# Alternatively, using Seaborn library to demonstrate pairplot with better visualization. Here we have used 'hue' parameter to separte out the target classes in different colors
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species", size=3,diag_kind='kde');
plt.show()
# Out:
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Since we will be getting n x n plots for n features, pairplot may become complex when we have more number of feature say like 10 or so on. So in such cases, the best bet will be using a dimensionality reduction technique to map data into 2d plane and visualizing it using a 2d scatter plot.

# %% [markdown]
# ### Box plot
# This is the type of plot that can be used to obtain more of the statistical details about the data. The straight lines at the maximum and minimum are also called as whiskers. Points outside of whiskers will be inferred as an outliers. The box plot gives us a representation of 25th, 50th ,75th quartiles.From box plot we can also see the Interquartile range(IQR) where maximum details of the data will be present. It also gives us a clear overview of outlier points in the data.

# %%
# Box plotting using inbuilt plot() of DataFrame
iris.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# boxplotting using matplotlib library
plt.boxplot(x=iris['sepal_length'],vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ec2d6aef70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ec2d6aefd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ec292678e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ec293cbf10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ec29019520>],
#  'means': []}

# %%
# boxplotting using seaborn library
sns.boxplot(x='sepal_length',orient="h",data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
# boxplotting using seaborn library ; In this case, boxplot against indepent feature 'sepal_length' is plotted by target class (setosa, versicolor, virginica)
sns.boxplot(x='species',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# Here x is the variable to be predicted and y is the independent feature. These box plots comes under univariate analysis, which means that we are exploring data only with one variable i.e here we are just checking influence of feature sepal_length on the class species and not between any two independent features.
#
# Using the box plot, as mentioned above we can see how much of data is present in 1st quartile and how much points are outliers etc. From the above plot for the class Setosa and versicolor we can see that there are no outlier present,however outlier presents for class viriginca. Such details about outliers and so on will help us to well prepare the data before sending it to a model, as outlier impacts a lot of Machine learning models.

# %% [markdown]
# ### Violin Plot
#
# Violin plots are similar to box plots, except that they also show the probability density of the data at different values. These plots include a marker for the median of the data and a box indicating the interquartile range, as in the standard box plots. Overlaid on this box plot is a kernel density estimation. Like box plots, violin plots are used to represent comparison of a variable distribution (or sample distribution) across different "categories".
#
# A violin plot is more informative than a plain box plot. In fact while a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data.

# %%
#Violin plot using matplotlib library
iris_independent_feature = iris.drop('species',axis=1)
plt.violinplot(iris_independent_feature)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1ec2d75c3d0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1ec2d75c220>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1ec2d8d6250>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1ec2d8d65e0>}

# %%
# Alternatively, we can use seaborn library for better visualization
sns.violinplot(x='species',y='sepal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# From the above violin plot we can infer that median of Setosa classe is around 5, versicolor is just below 6 and 6.5 for virginica with respect to sepal_length. importantly, virginica has left skewed distribution with respect to sepal_length

# %% [markdown]
# ##### Let's explore violin plot grouped by categorical features

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# violin plot to demonstarte distribution of a numerical feature
ax = sns.violinplot(x=tips['total_bill'])

# %%
# Draw a vertical violinplot grouped by a categorical variable
ax = sns.violinplot(x='day',y='total_bill',data=tips)

# %%
# Draw a violinplot with nested grouping by two categorical variables
ax = sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips)

# %%
# Draw split violins to compare the across the hue variable:
ax = sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips,split=True)

# %% [markdown]
# ### Distribution plot
#
# A distribution plot displays a distribution and range of a set of numeric values plotted against a dimension. You can display this chart in three different ways, you can just have the value points displayed showing the distribution, or you can display the bounding box which shows the range or use a combination of both.

# %%
# To check the distribution you can use kde or density plot using inbuilt plot()
ax=iris.plot(kind ='kde')
ax.set_title("kde plot")
ax.set_xlabel("length/width size")
# Out:
# Text(0.5, 0, 'length/width size')

# %%
ax=iris.plot(kind ='density')
ax.set_title("density plot")
ax.set_xlabel("length/width size")
# Out:
# Text(0.5, 0, 'length/width size')

# %% [markdown]
# #### Histograms
# A great way to get started exploring a single variable is with the histogram. A histogram divides the variable into bins, counts the data points in each bin, and shows the bins on the x-axis and the counts on the y-axis. In this case, the bins will be an interval of length/width size representing the length/width size of sepal/petal and the count will be the number of sepal/petal falling into that interval. The binwidth is the most important parameter for a histogram and we should always try out a few different values of binwidth to select the best one for our data.

# %%
ax=iris.plot(kind='hist', bins=5)
ax.set_xlabel('petal/speal size')
ax.legend()

# %%
# Alternatively we can use matplotlib library for histogram plotting for each feature
plt.hist(iris_independent_feature,bins=3)
plt.legend(['sepal_length','sepal_width','petal_length','petal_width'])
plt.xlabel('size')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ##### Distplot flexibly plot a univariate distribution of observations, Show a default plot with a kernel density estimate and histogram with bin size determined automatically
#
# This function combines the matplotlib ``hist`` function (with automatic calculation of a good default bin size) with the seaborn :func:`kdeplot`and :func:`rugplot` functions

# %%
# To plot distplot for sepal_length
sns.distplot(iris_independent_feature['sepal_length'],label='sepal_length',kde=True,hist=True)
# Out:
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# Now that we understand how a density plot is made and what it represents, let’s see how it can solve our problem of visualizing the length/width size of sepals/petals. To show the distributions on the same plot, we can iterate through the sepal/petal features, each time calling distplot with the kernel density estimate set to True and the histogram set to True. The code to draw the density plot with multiple feature is below:

# %%
# If we want to compare the distribution of each feature, we can use for loop
labels = ['sepal_length','sepal_width','petal_length','petal_width']
for label in labels:
    sns.distplot(iris_independent_feature[label],label=label,kde=True,hist=True)
plt.legend()
# Out:
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### JointPlot
#
# In a single figure we can do both univariate as well as bivariate analysis. The main plot will give us a bivariate analysis, whereas on the top and right side we will get univariate plots of both the variables that were considered
#
# There are variety of option you can choose from, which can be tuned using kind parameter in seaborn’s jointplot function

# %%
sns.jointplot(x=iris['petal_length'],y=iris['sepal_length'],kind='scatter')

# %%
sns.jointplot(x=iris['petal_length'],y=iris['sepal_length'],kind='hex')

# %%
# The one shown below is of kind as KDE( Kernel Density Estimation) and it is represented in a contour diagram, 
# All points with same boundary will have the same value and the colour at a point depends on number of datapoints 
# i.e it will be light color when very few points had that value and will be darker with more points. 
# This is why at center it is darker and will be pale/lighter at the ends for this dataset.
sns.jointplot(x=iris['petal_length'],y=iris['sepal_length'],kind='kde')

# %% [markdown]
# ### Bar Chart

# %%
iris.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris_independent_feature.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris_independent_feature.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Plotting horizontal bar
iris_independent_feature.iloc[0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
iris_features=iris_independent_feature.iloc[0].T.index
iris_features
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
# Alternatively, we can plot bar chart using matplotlib library
plt.bar(iris_features,iris_independent_feature.iloc[0])
plt.xlabel('independent features')
plt.ylabel('length/width size')
plt.title('Example of bar chart')
# Out:
# Text(0.5, 1.0, 'Example of bar chart')

# %%
# Alternatively, we can plot bar chart using seaborn library
sns.barplot(iris_features,iris_independent_feature.iloc[0])
plt.xlabel('independent features')
plt.ylabel('length/width size')
plt.title('Example of bar chart')
# Out:
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Example of bar chart')

# %% [markdown]
# ### Line plots:
# This is the plot that you can see in nook and corners of any sort of analysis between 2 variables. The line plots are nothing but the values on series of datapoints will be connected with straight lines.

# %%
# Demonstrate line plot using in-built dataframe plot()
iris.plot(kind ='line')
# Out:
# <AxesSubplot:>

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
# Linechart can be plotted using matplotlib library
import numpy as np
x=np.arange(0,10)
y=np.arange(11,21)

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
# Creating subplot with 4 different types of line chart
## Creating Subplots
plt.subplot(2,2,1) # 1st subplot of 2X2 Matrices
plt.plot(x,y,'r--') # red color dotted line
plt.subplot(2,2,2) # 2nd subplot of 2X2 Matrices
plt.plot(x,y,'g*--') # green colored with dotted line and points marked as *
plt.subplot(2,2,3) # 3rd subplot of 2X2 Matrices
plt.plot(x,y,'b') # blue colored line
plt.subplot(2,2,4) # 4th subplot of 2X2 Matrices
plt.plot(x,y,'go') # green colored points with no line

# %%
# Another example : Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 
# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
# Same example implemented through Seaborn library : Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 
# Line plot the points using seaborn library 
sns.lineplot(x,y)
# Out:
# C:\Users\DasAm\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'sine wave form'}>

# %%
# Lets see few more example of lineplot using seaborn
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>
